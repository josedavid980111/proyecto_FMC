# %%
import re, string
#archivo = input("Nombre del archivo: ")
#f=open(archivo+".txt").read()
f=open("Ejemplo.txt").read()

#float y double
Aux1=re.sub(r"[.]","", f)
Aux2=re.sub("\s",",", Aux1)
Aux3=re.sub('"', '{', Aux2)
Aux4=re.sub("="+r",*"+"[{]+([{]*\w*"+r",*"+")*", "={", Aux3)
Aux5=re.sub("="+r",*"+"[{]+(\w*"+r",*)*[}]*", "=valor", Aux4)
Aux6=re.sub(r",*"+"\["+r",*"+"\]", "[]", Aux5)
Aux7=re.sub("(\[]"+r",*)+", "[]", Aux6)
Aux=re.sub("'", "", Aux7)



#ExpReg1=["int"+r",+"+"\w+", "String"+r",+"+"\w+", "float"+r",+"+"\w+", "Integer"+r",+"+"\w+", "double"+r",+"+"\w+", "char"+r",+"+"\w+"]
#ExpReg2=["int"+r",+"+"\w+"+r",*"+"=*", "String"+r",+"+"\w+"+r",*"+"=*", "float"+r",+"+"\w+"+r",*"+"=*", "Integer"+r",+"+"\w+"+r",*"+"=*", "double"+r",+"+"\w+"+r",*"+"=*", "char"+r",+"+"\w+"+r",*"+"=*"]


ExpReg1=[r"int,*", r"String,*", r"float,*", r"Integer,*", r"double,*", r"char,*", r"byte,*", r"boolean,*", r"long,*"]

ResTipo1=["int", "String", "float", "Integer", "double", "char", "byte", "boolean", "long"]


Busqueda1=["int[]", "String[]", "float[]", "Integer[]", "double[]", "char[]", "byte[]", "boolean[]", "long[]"]




##############################################################################






Res1=[]
Res2=[]
Res3=[]
for i in range(len(ResTipo1)):
    ResAux1=[]
    ResAux2=[]
    A1=""
    Au1=""
    ExpReg11=""
    Exp11=""
    ExpReg12=""
    Exp12=""
    
    bandera1=True
    banderaF1=False
    inicio1=0
    
    Aux11=""
    Aux12=""
    
    ExpReg14=""
    Exp14=""
    
    
    ExpReg11 = ResTipo1[i]+r",+"+"\w+"
    Exp11 = re.findall(ExpReg11,Aux,flags=re.MULTILINE)
    
    ExpReg12 = ResTipo1[i]+r",+"+"\w+"+r",*"+"=*"+r",*"
    Exp12 = re.findall(ExpReg12,Aux,flags=re.MULTILINE)
    
    while banderaF1==False and len(Exp11)>0:
        if len(Exp11)==len(Exp12):
            x=0
            while x < len(Exp11) and bandera1==True:

                Aux11=Exp11[x]
                Aux12=Exp12[x]
                if(Aux11!=Aux12):
                    bandera1=False
                if x+1 == len(Exp11) and bandera1==True :
                    banderaF1=True
                    
                x+=1
            bandera1=True


        if banderaF1==False and inicio1==0:
            ExpReg11=ExpReg11+r",*"+"=*"+r",*"
            ExpReg12=ExpReg12+"\w*"+r",*"+"\[*"+"\]*"+r",*"+"=*"+r",*"
            inicio1+=1
        elif banderaF1==False and inicio1==1:
            ExpReg11=ExpReg11+"\w*"+r",*"+"\[*"+"\]*"+r",*"+"=*"+r",*"
            ExpReg12=ExpReg12+"\w*"+r",*"+"\[*"+"\]*"+r",*"+"=*"+r",*"

        Exp11 = re.findall(ExpReg11,Aux,flags=re.MULTILINE)
        Exp12 = re.findall(ExpReg12,Aux,flags=re.MULTILINE)
        

    #print(Exp12)

    
    for x in range(len(Exp12)):
        Au1=re.sub(ExpReg1[i],"", Exp12[x])
        A1=re.sub(r",*"+r"="+r",*"+"\w*"+r",*"," ", Au1)
        ExpReg14= "\w+"
        Exp14 = re.findall(ExpReg14,A1)
        for y in range(len(Exp14)):
            ResAux1.append(Exp14[y])
    if(len(ResAux1)>0):
        ResAux2 = list(set(ResAux1))
    Res1.append(list(ResAux2))

    
#for x in range(len(Exp2)):
    


#+"\w*"+r",*"+"=*"




##############################################################################


ExpReg13 = "\w+"+"\[]"
Exp13 = re.findall(ExpReg13,Aux,flags=re.MULTILINE)
Exp14 = list(set(Exp13))

x=0
while x<len(Busqueda1):
    try:
        i=Exp14.index(Busqueda1[x])
        Exp14.pop(i)
        x+=1
    except:
        x+=1
Exp15=[]
Au1=""
for x in range(len(Exp14)):
        Au1=re.sub("\[]","", Exp14[x])
        Res2.append(Au1)
    
for x in range(len(Exp14)):
        A1=re.sub("\[]","", Exp14[x])
        Exp15.append(A1)
        y=0
        while y<len(Res1):
            try:
                i=Res1[y].index(A1)
                Res1[y].pop(i)
                y+=1
            except:
                y+=1
                



##############################################################################



for i in range(len(ResTipo1)):
    ResAux1=[]
    ResAux2=[]
    A1=""
    Au1=""
    ExpReg11=""
    Exp11=""
    ExpReg12=""
    Exp12=""
    
    bandera1=True
    banderaF1=False
    inicio1=0
    
    Aux11=""
    Aux12=""
    
    ExpReg14=""
    Exp14=""
    
    
    ExpReg11 = ResTipo1[i]+r",*"+"\[]"+r",*"+"\w+"
    Exp11 = re.findall(ExpReg11,Aux,flags=re.MULTILINE)
    
    ExpReg12 = ResTipo1[i]+r",*"+"\[]"+r",*"+"\w+"+r",*"+"=*"+r",*"
    Exp12 = re.findall(ExpReg12,Aux,flags=re.MULTILINE)
    while banderaF1==False and len(Exp11)>0:
        if len(Exp11)==len(Exp12):
            x=0
            while x < len(Exp11) and bandera1==True:

                Aux11=Exp11[x]
                Aux12=Exp12[x]
                if(Aux11!=Aux12):
                    bandera1=False
                if x+1 == len(Exp11) and bandera1==True :
                    banderaF1=True
                    
                x+=1
            bandera1=True


        if banderaF1==False and inicio1==0:
            ExpReg11=ExpReg11+r",*"+"=*"+r",*"
            ExpReg12=ExpReg12+"\w*"+r",*"+"\[*"+"\]*"+r",*"+"=*"+r",*"
            inicio1+=1
        elif banderaF1==False and inicio1==1:
            ExpReg11=ExpReg11+"\w*"+r",*"+"\[*"+"\]*"+r",*"+"=*"+r",*"
            ExpReg12=ExpReg12+"\w*"+r",*"+"\[*"+"\]*"+r",*"+"=*"+r",*"

        Exp11 = re.findall(ExpReg11,Aux,flags=re.MULTILINE)
        Exp12 = re.findall(ExpReg12,Aux,flags=re.MULTILINE)
    
    #print(Exp12)

    
    for x in range(len(Exp12)):
        Au1=re.sub(ExpReg1[i],"", Exp12[x])
        A1=re.sub(r",*"+r"="+r",*"+"\w*"+r",*"," ", Au1)
        ExpReg14= "\w+"
        Exp14 = re.findall(ExpReg14,A1)
        for y in range(len(Exp14)):
            ResAux1.append(Exp14[y])
    if(len(ResAux1)>0):
        ResAux2 = list(set(ResAux1))
    Res3.append(list(ResAux2))

    
#for x in range(len(Exp2)):
    


#+"\w*"+r",*"+"=*"
                  



##############################################################################

NumTotTiposUtilizados=0
NumTotVarDeclaradasPorTipo=[]
TotVarDeclaradas=0
for x in range(len(ResTipo1)):
    NumTotVarDeclaradasPorTipo.append(len(Res1[x]))
    if len(Res1[x])>0:
        NumTotTiposUtilizados+=1
        TotVarDeclaradas+=len(Res1[x])



for y in range(len(Res3)):
    for w in range(len(Res3[y])):
        Res2.append(Res3[y][w])


NumTotVarArreglos=len(Res2)        

if len(Res2)>0:
    NumTotTiposUtilizados+=1
    TotVarDeclaradas+=len(Res2)

##############################################################################







cont=0
SinEspacio=[]
for y in range(len(Res1)):
    for x in range(len(Res1[y])):
        SinEspacio=[]
        ExpReg12=r"\b"+Res1[y][x]+r"\b"+"\s*"+"="+"|"+r"\b"+Res1[y][x]+r"\b"+"\s*"+r",*"
        Exp11 = re.findall(ExpReg12,f,flags=re.MULTILINE)
        for w in range(len(Exp11)):
            EliminaEspacio=re.sub("\s","", Exp11[w])
            SinEspacio.append(EliminaEspacio)
            
        print(SinEspacio)
        if(SinEspacio[0]==Res1[y][x]+"="):
            cont+=1







##############################################################################








print("\033[1;4;31m"+"1- Numero total de variables declaradas")
print("\033[1;4;35m"+str(TotVarDeclaradas))
print("")

print("\033[1;4;31m"+"2- Numero total de tipos utilizados en las declaraciones encontradas")
print("\033[1;4;35m"+str(NumTotTiposUtilizados))
print("")

print("\033[1;31m"+"3- Numero total de variables declaradas de cada tipo")
for x in range(len(ResTipo1)):
    print("\033[1;30m"+ResTipo1[x])
    print("\033[1;35m"+str(NumTotVarDeclaradasPorTipo[x]))
    print("")
print("\033[1;4;30m"+"Arreglos")
print("\033[1;35m"+str(len(Res2)))
print("")

print("\033[4;31m"+"4- Numero total de variables inicializada")
print("\033[1;35m"+str(cont))
print("")

print("\033[4;31m"+"5- Numero total de variables de tipo arreglo")
print("\033[1;35m"+str(NumTotVarArreglos))
print("")

print("\033[4;31m"+"6- Clasificación de todos los nombres de variables por tipo declarado")

for x in range(len(ResTipo1)):
    print("\033[1;30m"+ResTipo1[x])
    print("\033[1;35m"+str(Res1[x]))
    print("")

print("\033[1;30m"+"Arreglos")
print("\033[1;35m"+str(Res2))
# Out:
# ['i=', 'i', 'i', 'i', 'i']
# ['tcpPort=', 'tcpPort']
# ['j=', 'j', 'j', 'j']
# ['eruj']
# ['golpes=', 'golpes=', 'golpes', 'golpes']
# ['aux2', 'aux2=', 'aux2', 'aux2=']
# ['tcpIP=', 'tcpIP,']
# ['idJuego=', 'idJuego', 'idJuego=', 'idJuego', 'idJuego']
# ['name=', 'name']
# ['jgt']
# ['ikujhd=']
# ['doneSignal', 'doneSignal', 'doneSignal=', 'doneSignal']
# ['conexion=', 'conexion', 'conexion']
# ['porExito=', 'porExito']
# ['promedio=', 'promedio', 'promedio']
# ['buffer', 'buffer=', 'buffer,', 'buffer']
# ['ohwd']
# ['jugadores=', 'jugadores', 'jugadores=', 'jugadores', 'jugadores', 'jugadores']
# ['time', 'time=', 'time=', 'time', 'time']
# ['tiempo=', 'tiempo', 'tiempo=', 'tiempo']
# ['golpe', 'golpe']
# 1- Numero total de variables declaradas
# 22
#
# 2- Numero total de tipos utilizados en las declaraciones encontradas
# 9
#
# 3- Numero total de variables declaradas de cada tipo
# int
# 6
#
# String
# 3
#
# float
# 2
#
# Integer
# 1
#
# double
# 3
#
# char
# 0
#
# byte
# 1
#
# boolean
# 2
#
# long
# 3
#
# Arreglos
# 1
#
# 4- Numero total de variables inicializada
# 13
#
# 5- Numero total de variables de tipo arreglo
# 1
#
# 6- Clasificación de todos los nombres de variables por tipo declarado
# int
# ['i', 'tcpPort', 'j', 'eruj', 'golpes', 'aux2']
#
# String
# ['tcpIP', 'idJuego', 'name']
#
# float
# ['jgt', 'ikujhd']
#
# Integer
# ['doneSignal']
#
# double
# ['conexion', 'porExito', 'promedio']
#
# char
# []
#
# byte
# ['buffer']
#
# boolean
# ['ohwd', 'jugadores']
#
# long
# ['time', 'tiempo', 'golpe']
#
# Arreglos
# ['args']

# %%
# Out:
# ['i =', 'i ', 'i', 'i ', 'i ']
# ['i=', 'i', 'i', 'i', 'i']
# ['tcpPort =', 'tcpPort']
# ['tcpPort=', 'tcpPort']
# ['j=', 'j', 'j', 'j']
# ['j=', 'j', 'j', 'j']
# ['eruj']
# ['eruj']
# ['golpes =', 'golpes =', 'golpes', 'golpes']
# ['golpes=', 'golpes=', 'golpes', 'golpes']
# ['aux2', 'aux2 =', 'aux2', 'aux2 =']
# ['aux2', 'aux2=', 'aux2', 'aux2=']
# ['tcpIP =', 'tcpIP,']
# ['tcpIP=', 'tcpIP,']
# ['idJuego=', 'idJuego', 'idJuego =', 'idJuego', 'idJuego']
# ['idJuego=', 'idJuego', 'idJuego=', 'idJuego', 'idJuego']
# ['name =', 'name']
# ['name=', 'name']
# ['jgt']
# ['jgt']
# ['ikujhd=']
# ['ikujhd=']
# ['doneSignal', 'doneSignal', 'doneSignal =', 'doneSignal']
# ['doneSignal', 'doneSignal', 'doneSignal=', 'doneSignal']
# ['conexion=', 'conexion', 'conexion']
# ['conexion=', 'conexion', 'conexion']
# ['porExito=', 'porExito']
# ['porExito=', 'porExito']
# ['promedio =', 'promedio', 'promedio ']
# ['promedio=', 'promedio', 'promedio']
# ['buffer', 'buffer =', 'buffer,', 'buffer']
# ['buffer', 'buffer=', 'buffer,', 'buffer']
# ['ohwd']
# ['ohwd']
# ['jugadores =', 'jugadores', 'jugadores =', 'jugadores', 'jugadores', 'jugadores']
# ['jugadores=', 'jugadores', 'jugadores=', 'jugadores', 'jugadores', 'jugadores']
# ['time', 'time =', 'time =', 'time', 'time']
# ['time', 'time=', 'time=', 'time', 'time']
# ['tiempo =', 'tiempo ', 'tiempo =', 'tiempo ']
# ['tiempo=', 'tiempo', 'tiempo=', 'tiempo']
# ['golpe', 'golpe']
# ['golpe', 'golpe']
# 13
