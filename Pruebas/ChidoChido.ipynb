# %%
import re, string
#archivo = input("Nombre del archivo: ")
#f=open(archivo+".txt").read()
f=open("Ejemplo.txt").read()

#float y double
Aux1=re.sub(r"[.]","", f)
Aux2=re.sub("\s",",", Aux1)
Aux3=re.sub('"', '', Aux2)
Aux=re.sub("'", "", Aux3)



ExpReg1=["int"+r",+"+"\w+", "String"+r",+"+"\w+", "float"+r",+"+"\w+", "Integer"+r",+"+"\w+", "double"+r",+"+"\w+", "char"+r",+"+"\w+"]
ExpReg2=["int"+r",+"+"\w+"+r",*"+"=*", "String"+r",+"+"\w+"+r",*"+"=*", "float"+r",+"+"\w+"+r",*"+"=*", "Integer"+r",+"+"\w+"+r",*"+"=*", "double"+r",+"+"\w+"+r",*"+"=*", "char"+r",+"+"\w+"+r",*"+"=*"]


ExpReg3=[r"int,*", r"String,*", r"float,*", r"Integer,*", r"double,*", r"char,*"]

ResTipo1=["int", "String", "float", "Integer", "double", "char"]
Res1=[]

# %%
for i in range(len(ResTipo1)):
    ResAux1=[]
    A1=""
    Au1=""
    ExpReg11=""
    Exp11=""
    ExpReg12=""
    Exp12=""
    
    bandera1=True
    banderaF1=False
    inicio1=0
    
    Aux11=""
    Aux12=""
    
    ExpReg14=""
    Exp14=""
    
    
    ExpReg11 = ExpReg1[i]
    Exp11 = re.findall(ExpReg11,Aux,flags=re.MULTILINE)
    
    ExpReg12 = ExpReg2[i]
    Exp12 = re.findall(ExpReg12,Aux,flags=re.MULTILINE)
    
    while banderaF1==False and len(Exp11)>0:
        if len(Exp11)==len(Exp12):
            x=0
            while x < len(Exp11) and bandera1==True:

                Aux11=Exp11[x]
                Aux12=Exp12[x]
                if(Aux11!=Aux12):
                    bandera1=False
                if x+1 == len(Exp11) and bandera1==True :
                    banderaF1=True
                x+=1
            bandera1=True


        if banderaF1==False and inicio1==0:
            ExpReg11=ExpReg11+r",*"+"=*"
            ExpReg12=ExpReg12+"\w*"+r",*"+"=*"
            inicio1+=1
        elif banderaF1==False and inicio1==1:
            ExpReg11=ExpReg11+"\w*"+r",*"+"=*"
            ExpReg12=ExpReg12+"\w*"+r",*"+"=*"

        Exp11 = re.findall(ExpReg11,Aux,flags=re.MULTILINE)
        Exp12 = re.findall(ExpReg12,Aux,flags=re.MULTILINE)
        

    #print(Exp12)

    
    for x in range(len(Exp12)):
        Au1=re.sub(ExpReg3[i],"", Exp12[x])
        A1=re.sub(r",*"+r"="+r",*"+"\w*"+r",*"," ", Au1)
        ExpReg14= "\w+"
        Exp14 = re.findall(ExpReg14,A1)
        for y in range(len(Exp14)):
            ResAux1.append(Exp14[y])
    print(ResTipo1[i])
    print(ResAux1)
    Res1.append(ResAux1)
print(Res1)
    
#for x in range(len(Exp2)):
    


#+"\w*"+r",*"+"=*"
# Out:
# int
# ['jugadores', 'eys', 'aux2', 'golpes', 'tcpPort', 'j', 'i']
# String
# ['idJuego', 'idJuego', 'tcpIP', 'name']
# float
# []
# Integer
# ['doneSignal']
# double
# ['conexion', 'promedio', 'porExito']
# char
# ['ikujhd']
# [['jugadores', 'eys', 'aux2', 'golpes', 'tcpPort', 'j', 'i'], ['idJuego', 'idJuego', 'tcpIP', 'name'], [], ['doneSignal'], ['conexion', 'promedio', 'porExito'], ['ikujhd']]

# %%
import re, string
#archivo = input("Nombre del archivo: ")
#f=open(archivo+".txt").read()
f=open("Ejemplo.txt").read()

#float y double
Aux1=re.sub(r"[.]","", f)
Aux2=re.sub("\s",",", Aux1)
Aux3=re.sub('"', '', Aux2)
Aux4=re.sub("'", "", Aux3)
Aux=re.sub(";", "", Aux4)



ExpReg4=["int"+r",+"+"\w+"+r",*"+"\[* *\]*", "String"+r",+"+"\w+"+r",*"+"\[* *\]*", "float"+r",+"+"\w+"+r",*"+"\[* *\]*", "Integer"+r",+"+"\w+"+r",*"+"\[* *\]*", "double"+r",+"+"\w+"+r",*"+"\[* *\]*", "char"+r",+"+"\w+"+r",*"+"\[* *\]*"]
ExpReg5=["int"+r",+"+"\w+"+r",*"+"\[* *\]*"+r",*"+"=*", "String"+r",+"+"\w+"+r",*"+"\[* *\]*"+r",*"+"=*", "float"+r",+"+"\w+"+r",*"+"\[* *\]*"+r",*"+"=*", "Integer"+r",+"+"\w+"+r",*"+"\[* *\]*"+r",*"+"=*", "double"+r",+"+"\w+"+r",*"+"\[* *\]*"+r",*"+"=*", "char"+r",+"+"\w+"+r",*"+"\[* *\]*"+r",*"+"=*"]


ExpReg6=[r"int,*", r"String,*", r"float,*", r"Integer,*", r"double,*", r"char,*"]

ResTipo2=["int", "String", "float", "Integer", "double", "char"]
Res2=[]

# %%
for i in range(len(ResTipo2)):
    ResAux2=[]
    A2=""
    Au2=""
    ExpReg21=""
    Exp21=""
    ExpReg22=""
    Exp22=""
    
    bandera2=True
    banderaF2=False
    inicio2=0
    
    Aux21=""
    Aux22=""
    
    ExpReg24=""
    Exp24=""
    
    
    ExpReg21 = ExpReg4[i]
    Exp21 = re.findall(ExpReg21,Aux,flags=re.MULTILINE)
    
    ExpReg22 = ExpReg5[i]
    Exp22 = re.findall(ExpReg22,Aux,flags=re.MULTILINE)
    
    while banderaF2==False and len(Exp21)>0:
        if len(Exp21)==len(Exp22):
            x=0
            while x < len(Exp21) and bandera2==True:

                Aux21=Exp21[x]
                Aux22=Exp22[x]
                if(Aux21!=Aux22):
                    bandera2=False
                if x+1 == len(Exp21) and bandera2==True :
                    banderaF2=True
                x+=1
            bandera2=True


        if banderaF2==False and inicio2==0:
            ExpReg21=ExpReg21+r",*"+"=*"
            ExpReg22=ExpReg22+"\w*"+r",*"+"\[+ *\]*"+r",*"+"=*"
            inicio2+=1
        elif banderaF2==False and inicio2==1:
            ExpReg21=ExpReg21+"\w*"+r",*"+"\[+ *\]*"+r",*"+"=*"
            ExpReg22=ExpReg22+"\w*"+r",*"+"\[+ *\]*"+r",*"+"=*"

        Exp21 = re.findall(ExpReg21,Aux,flags=re.MULTILINE)
        Exp22 = re.findall(ExpReg22,Aux,flags=re.MULTILINE)

    #print(Exp12)

    
    for x in range(len(Exp22)):
        Au2=re.sub(ExpReg6[i],"", Exp22[x])
        A2=re.sub(r",*"+r"="+r",*"+"\w*"+r",*"," ", Au2)
        ExpReg24= "\w+"
        Exp24 = re.findall(ExpReg24,A2)
        for y in range(len(Exp24)):
            ResAux2.append(Exp24[y])
    print(ResTipo2[i])
    print(ResAux2)
    Res2.append(ResAux2)
print(Res2)
    
#for x in range(len(Exp2)):
    


#+"\w*"+r",*"+"=*"
# Out:
# int
# []
# String
# []
# float
# []
# Integer
# ['doneSignal']
# double
# []
# char
# ['ikujhd']
# [[], [], [], ['doneSignal'], [], ['ikujhd']]
